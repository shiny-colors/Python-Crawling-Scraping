# %%
import requests
from urllib.request import urlopen
import pandas as pd
import numpy as np

# %%
#エクセルファイルの書き込み
f = urlopen("https://www.jpx.co.jp/markets/statistics-equities/misc/01.html")
encoding = f.info().get_content_charset(failobj="utf-8")
text = f.read().decode(encoding)
data = urlopen("https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls")
with open("data_j.xls", "wb") as f:
    f.write(data.read())

# %%
#エクセルファイルの読み込み
input_book = pd.ExcelFile("data_j.xls")
input_sheet_name = input_book.sheet_names
print(input_sheet_name)

#DataFrameとして一つ目のsheetを読込
input_sheet_df = input_book.parse(input_sheet_name[0])
# Out:
# ['Sheet1']

# %%
#データフレームを加工してMySQLに格納
# Out:
#             日付   コード                                                銘柄名  \
# 0     20190228  1301                                                 極洋
# 1     20190228  1305                                      ダイワ上場投信－トピックス
# 2     20190228  1306                                     ＴＯＰＩＸ連動型上場投資信託
# 3     20190228  1308                                  上場インデックスファンドＴＯＰＩＸ
# 4     20190228  1309                               上海株式指数・上証５０連動型上場投資信託
# 5     20190228  1310                                 ダイワ上場投信－トピックス・コア３０
# 6     20190228  1311                            ＴＯＰＩＸ　Ｃｏｒｅ　３０　連動型上場投資信託
# 7     20190228  1312                         ラッセル野村小型コア・インデックス連動型上場投資信託
# 8     20190228  1313                         サムスンＫＯＤＥＸ２００証券上場指数投資信託［株式］
# 9     20190228  1319                                 日経３００株価指数連動型上場投資信託
# 10    20190228  1320                                      ダイワ上場投信－日経２２５
# 11    20190228  1321                                     日経２２５連動型上場投資信託
# ...
