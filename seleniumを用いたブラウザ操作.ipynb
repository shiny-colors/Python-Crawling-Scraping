# %%
####seleniumを用いたブラウザ操作####
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import requests
from urllib.request import urlopen
import pandas as pd
import numpy as np
import time
import itertools

# %%
#browserを読み込み検索窓にワードを入力して検索
def get_url(keyword):
    #seleniumでブラウザを読み込み
    browser = webdriver.Firefox()
    browser.get("https://www.google.com/")   #URLを検索
    
    #検索ワードを入力して検索
    browser.find_element_by_id("gsr").send_keys(keyword)   #検索ワード
    time.sleep(0.5)
    browser.find_element_by_id("gsr").send_keys(Keys.RETURN)
    #browser.find_element_by_name("btnK").click()   #こちらでもok検索する
    return browser

# %%
#次ページに進む
def next_page(browser, wait_time1, wait_time2):
    time.sleep(wait_time1)
    try:
        flag = 0
        browser.find_element_by_css_selector("a#pnnext").click()
    except NoSuchElementException:
        flag = 1
    time.sleep(wait_time2)
    return flag

# %%
#検索結果を取得
def get_search(browser):
    all_search = browser.find_elements_by_class_name("rc")
    n = len(all_search)
    title_list = [j for j in range(n)]
    url_list = [j for j in range(n)]
    display_url_list = [j for j in range(n)]
    description_list = [j for j in range(n)]

    for j in range(n):
        title_list[j] = all_search[j].find_element_by_tag_name("h3").text
        url_list[j] = all_search[j].find_element_by_tag_name("a").get_attribute("href")
        display_url_list[j] = all_search[j].find_element_by_tag_name("cite").text
        try:
            description_list[j] = all_search[j].find_elements_by_class_name("st")[0].text
        except NoSuchElementException:
            description_list[j] = ""
    
    #numpy arrayに変換
    title = np.array(title_list)
    url = np.array(url_list)
    display_url = np.array(display_url_list)
    description = np.array(description_list)
    return title, url, display_url, description

# %%
#任意のページまで検索結果を取得
pages = 10   #取得するページ数
browser = get_url("アイドルマスターシンデレラガールズ")   #任意のキーワードで検索
time.sleep(0.5)   #待ち時間
title_list = [j for j in range(pages)]
url_list = [j for j in range(pages)]
display_url_list = [j for j in range(pages)]
description_list = [j for j in range(pages)]

for j in range(pages):
    #ページの情報を取得
    res = get_search(browser)
    title_list[j] = res[0]
    url_list[j] = res[1]
    display_url_list[j] = res[2]
    description_list[j] = res[3]

    #次のページへ
    flag = next_page(browser, 1.0, 0.5)
    if flag==1:
        break

# %%
#リストを変換してdata frameに格納
title = np.array(list(itertools.chain(*[title_list[j] for j in range(pages)])))
url = np.array(list(itertools.chain(*[url_list[j] for j in range(pages)])))
display_url = np.array(list(itertools.chain(*[display_url_list[j] for j in range(pages)])))
description = np.array(list(itertools.chain(*[description_list[j] for j in range(pages)])))
pd.DataFrame({'1. タイトル' : title, '2. 概要' : description, '3. URL' : url, '4. Dispaly URL' : display_url})   #取得結果を表示
# Out:
#                                               1. タイトル  \
# 0            ラブライブ！シリーズ公式 (@LoveLive_staff) | Twitter
# 1   ラブライブ！サンシャイン!! Aqours 3rd LoveLive! Tour ～WOND...
# 2   「ラブライブ！サンシャイン!!The School Idol Movie Over the ...
# 3    ラブライブ！スクールアイドルフェスティバル ～after school ACTIVITY ...
# 13                          froovie.jp/shop/c/c31011/
# 14                         www.sej.co.jp › セール・キャンペーン
# 15         https://www.ensky.co.jp/character/610.html
# 16                     https://lovelive-puchiguru.jp/
# 17                    https://realdgame.jp/zepp7_lls/
# 18          https://official-goods-store.jp/lovelive/
# 19  https://www.aeoncinema.com/cinema2/makuhari/mo...
# 20          https://official-goods-store.jp/lovelive/
# 21  https://www.aeoncinema.com/cinema2/makuhari/mo...
# 22                         lp-lls.bandaivisual.co.jp/
# 23           https://www.super-groupies.com/title/211
# 24        www.midland-sq-cinema.jp/movie_detail/17760
# 25  https://itunes.apple.com/jp/app/ラブライブ...スクフェス/...
# 26                      www.bandai.co.jp › トップ › 商品検索
# 27                   https://p-bandai.jp/chara/c2432/
# 28  https://play.google.com/store/apps/details?id=...
# 29      nijigencospa.com/itemlist/id/02286/mode/title
# ..                                                ...
# 59                  https://animeanime.jp › ニュース › 音楽
# 60                             cinecitta.co.jp › 作品案内
# 61                 lovelive-sunshine-winter-sega.com/
# 62                              https://lls.cocos.jp/
# 63                   gs.dengeki.com/tag/ラブライブ！サンシャイン/
# 64  https://syosetu.org/search/?mode=search&word=原...
# 65  https://www.4gamer.net › iPhone › Android › シン...
# 66  https://t.pia.jp/pia/event/event.do?eventBundl...
# 67     https://prtimes.jp › アパレル・ファッション › レディースファッション
# 68             https://realsound.jp › コラム › チャート一刀両断！
# 69                  www.ohtabooks.com/continue/vol57/
# 70  https://www.famitsu.com/news/201901/10170402.html
# 71     www6.nhk.or.jp/anime/topics/detail.html?i=5134
# 72            https://bandai-hobby.net/site/lovelive/
# 73           sunrise-inc.co.jp/work/news.php?id=16564
# 74  https://www.hakobura.jp/deep/2018/03/post-310....
# 75  https://comic-walker.com/contents/detail/KDCW_...
# 76          https://tamashii.jp/special/shf_lovelive/
# 77           https://www.tokaibus.jp/page.jsp?id=8114
# 78                   www.3coins.jp/lovelive_sunshine/
# 79                       lovelive-sunshine.info/64578
# 80              https://www.chara-ani.com › グッズ › カード
# 81   https://otamart.com › ... › ストラップ/ラバーストラップ(ラバスト)
# 82             blog.esuteru.com/archives/9289655.html
# 83                         https://anibu.jp › アニメニュース
# 84               onecall2ch.com/archives/9351160.html
# 85        www.cinemasunshine.co.jp/theater/ikebukuro/
# 86   https://books.google.co.jp/books?id=M5BnDwAAQBAJ
# 87               keian.hatenablog.com/category/ラブライブ！
# 88                         https://tarosoku.com › ゲーム
#
# [89 rows x 4 columns]

# %%
j = 0
print(title[j])
print(description[j])
# Out:
# ラブライブ！シリーズ公式 (@LoveLive_staff) | Twitter
# The latest Tweets from ラブライブ！シリーズ公式 (@LoveLive_staff). オールメディア展開するスクールアイドルプロジェクト、ラブライブ！シリーズの公式アカウントです。「プロジェクトラブライブ！」の各スタッフが、それぞれいろいろな情報をみなさんへ向けて ...
